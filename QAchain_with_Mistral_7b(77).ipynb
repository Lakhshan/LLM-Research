# %%
# !pip install -q optimum auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.0/301.0 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 112.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 84.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.3 MB/s eta 0:00:00
#   Building wheel for optimum (pyproject.toml) ... done

# %%
# !pip install git+https://github.com/huggingface/transformers.git@72958fcd3c98a7afdc61f953aa58c544ebda2f79
# Out:
# Collecting git+https://github.com/huggingface/transformers.git@72958fcd3c98a7afdc61f953aa58c544ebda2f79
#   Cloning https://github.com/huggingface/transformers.git (to revision 72958fcd3c98a7afdc61f953aa58c544ebda2f79) to /tmp/pip-req-build-_qs2dvtw
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-_qs2dvtw
#   Running command git rev-parse -q --verify 'sha^72958fcd3c98a7afdc61f953aa58c544ebda2f79'
#   Running command git fetch -q https://github.com/huggingface/transformers.git 72958fcd3c98a7afdc61f953aa58c544ebda2f79
#   Running command git checkout -q 72958fcd3c98a7afdc61f953aa58c544ebda2f79
#   Resolved https://github.com/huggingface/transformers.git to commit 72958fcd3c98a7afdc61f953aa58c544ebda2f79
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.34.0.dev0)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0.dev0) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers==4.34.0.dev0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (2023.7.22)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.34.0.dev0-py3-none-any.whl size=7746154 sha256=5db44fb059f76ae2bf5690fba8bd3eb6569c5a487ac61e804f99542510af4b3a
#   Stored in directory: /root/.cache/pip/wheels/9e/c6/66/2ffb1af58ffb2aac1352c978f7c5853a6e72bf988a7d0157bb
# Successfully built transformers
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.33.3
#     Uninstalling transformers-4.33.3:
#       Successfully uninstalled transformers-4.33.3
# Successfully installed huggingface-hub-0.16.4 tokenizers-0.14.0 transformers-4.34.0.dev0

# %%
# !pip install -q einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00

# %%
# !pip install -q sentence_transformers unstructured
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.1/275.1 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 19.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for sentence_transformers (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done

# %%
# !pip install -q chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.8/437.8 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 56.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 8.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
import os
import requests
from langchain.llms import HuggingFaceHub
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import UnstructuredURLLoader
from langchain.document_loaders import PyPDFLoader
from langchain.chains import RetrievalQA
from langchain.document_loaders import DirectoryLoader
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
url=["https://mistral.ai/news/announcing-mistral-7b/"]
loader = UnstructuredURLLoader(urls=url)
data = loader.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
chunks = text_splitter.split_documents(data)

# %%
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Loading the tokenizer from the `special_tokens_map.json` and the `added_tokens.json` will be removed in `transformers 5`,  it is kept for forward compatibility, but it is recommended to update your `tokenizer_config.json` by uploading it again. You will see the new `added_tokens_decoder` attribute that will store the relevant information.

# %%
persist_directory = 'pop'

# %%
vectorstore = Chroma.from_documents(chunks, embedding_function,persist_directory=persist_directory)

# %%
#retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
retriever = vectorstore.as_retriever()

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline
import torch

model = "TheBloke/Mistral-7B-Instruct-v0.1-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(model)


pipeline = pipeline(
    "text-generation", #task
    model=model,
    tokenizer=tokenizer,
    trust_remote_code=True,
    device_map="auto",
    max_length=2000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/__init__.py:24: UserWarning: Importing HuggingFacePipeline from langchain root module is no longer supported.
#   warnings.warn(
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/963 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
from langchain import HuggingFacePipeline
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0.5})
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/__init__.py:24: UserWarning: Importing HuggingFacePipeline from langchain root module is no longer supported.
#   warnings.warn(

# %%
llm
# Out:
# HuggingFacePipeline(cache=None, verbose=False, callbacks=None, callback_manager=None, tags=None, metadata=None, pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x793a072e6260>, model_id='gpt2', model_kwargs={'temperature': 0.5}, pipeline_kwargs=None, batch_size=4)

# %%
qa_chain = RetrievalQA.from_chain_type(llm=llm,
                                  chain_type="stuff",
                                  retriever=retriever,
                                  return_source_documents=True)

# %%
def process_llm_response(llm_response):
    print(llm_response['result'])
    print('\n\nSources:')
    for source in llm_response["source_documents"]:
        print(source.metadata['source'])

# %%
query = "What is the Text description about?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
llm_response
# Out:
#  What is the Text description about?
#
# The text describes the capabilities and performance of the Mistral 7B language model. It explains how it performs well on various metrics including MMLU, Commonsense Reasoning, World Knowledge, Reading comprehension for Mistral 7B and Llama 2 (7B/13/70B). It also explains that there are some differences between the evaluation and the LLaMA2 paper’s.
#
# The text also describes a feature called "Sliding Window Attention" (SWA) that Mistral 7B uses, which improves the efficiency of the attention mechanism.
#
# The text mentions that Mistral 7B is a quick demonstration that the base model can be easily fine-tuned to achieve compelling performance, but it is not yet ready for deployment in environments that require moderated outputs. The text also acknowledges the assistance of various teams and individuals who helped to develop and implement the model.
#
#
# Sources:
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# {'query': 'What is the Text description about?',
#  'result': ' What is the Text description about?\n\nThe text describes the capabilities and performance of the Mistral 7B language model. It explains how it performs well on various metrics including MMLU, Commonsense Reasoning, World Knowledge, Reading comprehension for Mistral 7B and Llama 2 (7B/13/70B). It also explains that there are some differences between the evaluation and the LLaMA2 paper’s.\n\nThe text also describes a feature called "Sliding Window Attention" (SWA) that Mistral 7B uses, which improves the efficiency of the attention mechanism.\n\nThe text mentions that Mistral 7B is a quick demonstration that the base model can be easily fine-tuned to achieve compelling performance, but it is not yet ready for deployment in environments that require moderated outputs. The text also acknowledges the assistance of various teams and individuals who helped to develop and implement the model.',
#  'source_documents': [Document(page_content='Results on MMLU, Commonsense Reasoning, World Knowledge and Reading comprehension for Mistral 7B and Llama 2 (7B/13/70B). Mistral 7B largely outperforms Llama 2 13B on all evaluations, except on knowledge benchmarks, where it is on par (this is likely due to its limited parameter count, which restricts the amount of knowledge it can compress).\n\nNote: Important differences between our evaluation and the LLaMA2 paper’s:\n\nFor MBPP, we use the hand-verified subset\n\nFor TriviaQA, we do not provide Wikipedia contexts\n\nFlash and Furious: Attention drift', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Get in touch with Mistral AI.\n\nPlease provide a valid email address.\n\nPlease provide your first name.\n\nPlease provide your last name.\n\nPlease provide your country.\n\nPlease provide your interests.\n\nBy submitting this form, you agree with our Terms of Service. We will process your information in accordance with our Privacy Policy.\n\nSubmit\n\nFrontier AI in your hands\n\nLinks\n\nDevelopers\n\nProduct\n\nCompany\n\nNews\n\nAbout\n\nContact Us\n\nCareers\n\nPrivacy Policy\n\nTerms of Service\n\nLinkedin\n-\n\nX\n-\n\nDiscord\n\n© 2023 Mistral AI, All rights reserved - Legal notice', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='For MBPP, we use the hand-verified subset\n\nFor TriviaQA, we do not provide Wikipedia contexts\n\nFlash and Furious: Attention drift\n\nMistral 7B uses a sliding window attention (SWA) mechanism (Child et al., Beltagy et al.), in which each layer attends to the previous 4,096 hidden states.\nThe main improvement, and reason for which this was initially investigated, is a linear compute cost of O(sliding_window.seq_len). In practice, changes made to FlashAttention and xFormers yield a 2x speed improvement for sequence length of 16k with a window of 4k. A huge thanks to Tri Dao and Daniel Haziza for helping include these changes on a tight schedule.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='The Mistral 7B Instruct model is a quick demonstration that the base model can be easily fine-tuned to achieve compelling performance.\nWe’re looking forward to engaging with the community on ways to make the model finally respect guardrails, allowing for deployment in environments requiring moderated outputs.\n\nAcknowledgements\n\nWe are grateful to CoreWeave for their 24/7 help in marshalling our cluster. We thank the CINECA/EuroHPC team, and in particular the operators of Leonardo, for their resources and help. We thank the maintainers of FlashAttention, vLLM, xFormers, Skypilot for their precious assistance in implementing new features and integrating their solutions into ours. We thank the teams of HuggingFace, AWS, GCP, Azure ML for their intense help in making our model compatible everywhere.\n\nGet in touch with Mistral AI.\n\nPlease provide a valid email address.\n\nPlease provide your first name.\n\nPlease provide your last name.\n\nPlease provide your country.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'})]}

# %%
query = "How is mistral-7b LLM better than LLama 2?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
llm_response
# Out:
#  It is not necessarily better than LLama 2. It is different. LLama 2 uses a technique named “CodeLlama” to be efficient on code related task. Mistral 7B uses a technique named “Grouped-query attention” (GQA) to be faster. LLama 2 and mistral 7B have different parameters sizes. LLama 2 70B is more efficient and performs better than Mistral 7B on code and reasoning tasks, but Mistral 7B outperforms LLama 2 13B on many benchmarks, including reading comprehension, math and flash and f
#
# ## Answer (1)
#
# As it is not mentioned what LLMs you are comparing, I'll assume you are comparing Mistral LLM with LLama model family (1 B, 2 B 90B, 2 B 117B, 3 B 40B, 13 B 130B, 2 B 129B, 7 B 34B).
#
# The information provided is that Mistral 7B is "the best 7B model to date", it outperforms Llama 2 13B on all benchmarks and is on par with Llama 34B on many benchmarks (since Llama 2 34B was not released).
#
# It also uses Grouped-query attention (GQA) for faster inference, which allows Mistral 7B model to have better inference times and performance compared to LLama model family. Additionally, Mistral 7B uses Sliding Window Attention (SWA) to handle longer sequences at smaller cost.
#
# It is also important to note that the performance comparison is based on the evaluation pipeline provided by the authors of the Mistral model.
#
# ## Answer (0)
#
# This statement is not complete and therefore cannot be answered with a yes or no. It does not specify what criteria is being used to compare the Mistral LLM with LLama models, or which LLama models exactly are being compared to the Mistral LLM.
#
# To answer the question, more context is needed on how the LLMs are being compared.
#
# Comment: @user8740689 I've added some context. Please let me know if there is more you need.
#
#
# Sources:
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# {'query': 'How is mistral-7b LLM better than LLama 2?',
#  'result': ' It is not necessarily better than LLama 2. It is different. LLama 2 uses a technique named “CodeLlama” to be efficient on code related task. Mistral 7B uses a technique named “Grouped-query attention” (GQA) to be faster. LLama 2 and mistral 7B have different parameters sizes. LLama 2 70B is more efficient and performs better than Mistral 7B on code and reasoning tasks, but Mistral 7B outperforms LLama 2 13B on many benchmarks, including reading comprehension, math and flash and f\n\n## Answer (1)\n\nAs it is not mentioned what LLMs you are comparing, I\'ll assume you are comparing Mistral LLM with LLama model family (1 B, 2 B 90B, 2 B 117B, 3 B 40B, 13 B 130B, 2 B 129B, 7 B 34B).\n\nThe information provided is that Mistral 7B is "the best 7B model to date", it outperforms Llama 2 13B on all benchmarks and is on par with Llama 34B on many benchmarks (since Llama 2 34B was not released).\n\nIt also uses Grouped-query attention (GQA) for faster inference, which allows Mistral 7B model to have better inference times and performance compared to LLama model family. Additionally, Mistral 7B uses Sliding Window Attention (SWA) to handle longer sequences at smaller cost.\n\nIt is also important to note that the performance comparison is based on the evaluation pipeline provided by the authors of the Mistral model.\n\n## Answer (0)\n\nThis statement is not complete and therefore cannot be answered with a yes or no. It does not specify what criteria is being used to compare the Mistral LLM with LLama models, or which LLama models exactly are being compared to the Mistral LLM.\n\nTo answer the question, more context is needed on how the LLMs are being compared.\n\nComment: @user8740689 I\'ve added some context. Please let me know if there is more you need.',
#  'source_documents': [Document(page_content='Download it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace\n\nMistral 7B is easy to fine-tune on any task. As a demonstration, we’re providing a model fine-tuned for chat, which outperforms Llama 2 13B chat.\n\nPerformance in details\n\nWe compared Mistral 7B to the Llama 2 family, and re-run all model evaluations ourselves for fair comparison.\n\nPerformance of Mistral 7B and different Llama models on a wide range of benchmarks. For all metrics, all models were re-evaluated with our evaluation pipeline for accurate comparison. Mistral 7B significantly outperforms Llama 2 13B on all metrics, and is on par with Llama 34B (since Llama 2 34B was not released, we report results on Llama 34B). It is also vastly superior in code and reasoning benchmarks.\n\nThe benchmarks are categorized by their themes:', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Developers\n\nProduct\n\nCompany\n\nNews\n\nContact Us\n\nMistral 7B\n\nThe best 7B model to date, Apache 2.0\n\nSeptember 27, 2023\n\nMistral AI team\n\nMistral AI team is proud to release Mistral 7B, the most powerful language model for its size to date.\n\nMistral 7B in short\n\nMistral 7B is a 7.3B parameter model that:\n\nOutperforms Llama 2 13B on all benchmarks\n\nOutperforms Llama 1 34B on many benchmarks\n\nApproaches CodeLlama 7B performance on code, while remaining good at English tasks\n\nUses Grouped-query attention (GQA) for faster inference\n\nUses Sliding Window Attention (SWA) to handle longer sequences at smaller cost\n\nWe’re releasing Mistral 7B under the Apache 2.0 license, it can be used without restrictions.\n\nDownload it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Results on MMLU, Commonsense Reasoning, World Knowledge and Reading comprehension for Mistral 7B and Llama 2 (7B/13/70B). Mistral 7B largely outperforms Llama 2 13B on all evaluations, except on knowledge benchmarks, where it is on par (this is likely due to its limited parameter count, which restricts the amount of knowledge it can compress).\n\nNote: Important differences between our evaluation and the LLaMA2 paper’s:\n\nFor MBPP, we use the hand-verified subset\n\nFor TriviaQA, we do not provide Wikipedia contexts\n\nFlash and Furious: Attention drift', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='The benchmarks are categorized by their themes:\n\nCommonsense Reasoning: 0-shot average of Hellaswag, Winogrande, PIQA, SIQA, OpenbookQA, ARC-Easy, ARC-Challenge, and CommonsenseQA.\n\nWorld Knowledge: 5-shot average of NaturalQuestions and TriviaQA.\n\nReading Comprehension: 0-shot average of BoolQ and QuAC.\n\nMath: Average of 8-shot GSM8K with maj@8 and 4-shot MATH with maj@4\n\nCode: Average of 0-shot Humaneval and 3-shot MBPP\n\nPopular aggregated results: 5-shot MMLU, 3-shot BBH, and 3-5-shot AGI Eval (English multiple-choice questions only)\n\nAn interesting metric to compare how models fare in the cost/performance plane is to compute “equivalent model sizes”. On reasoning, comprehension and STEM reasoning (MMLU), Mistral 7B performs equivalently to a Llama 2 that would be more than 3x its size. This is as much saved in memory and gained in throughput.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'})]}

# %%
query = "What are the different benchmarks used compare Mistral-7b with other models ?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
llm_response
# Out:
#  The different benchmarks used to compare Mistral-7b with other models are categorized as follows:
#
# Commonsense Reasoning: 0-shot average of Hellaswag, Winogrande, PIQA, SIQA, OpenbookQA, ARC-Easy, ARC-Challenge, and CommonsenseQA.
#
# World Knowledge: 5-shot average of NaturalQuestions and TriviaQA.
#
# Reading Comprehension: 0-shot average of BoolQ and QuAC.
#
# Math: Average of 8-shot GSM8K with maj@8 and 4-shot MATH
#
#
# Sources:
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# {'query': 'What are the different benchmarks used compare Mistral-7b with other models ?',
#  'result': ' The different benchmarks used to compare Mistral-7b with other models are categorized as follows:\n\nCommonsense Reasoning: 0-shot average of Hellaswag, Winogrande, PIQA, SIQA, OpenbookQA, ARC-Easy, ARC-Challenge, and CommonsenseQA.\n\nWorld Knowledge: 5-shot average of NaturalQuestions and TriviaQA.\n\nReading Comprehension: 0-shot average of BoolQ and QuAC.\n\nMath: Average of 8-shot GSM8K with maj@8 and 4-shot MATH',
#  'source_documents': [Document(page_content='Developers\n\nProduct\n\nCompany\n\nNews\n\nContact Us\n\nMistral 7B\n\nThe best 7B model to date, Apache 2.0\n\nSeptember 27, 2023\n\nMistral AI team\n\nMistral AI team is proud to release Mistral 7B, the most powerful language model for its size to date.\n\nMistral 7B in short\n\nMistral 7B is a 7.3B parameter model that:\n\nOutperforms Llama 2 13B on all benchmarks\n\nOutperforms Llama 1 34B on many benchmarks\n\nApproaches CodeLlama 7B performance on code, while remaining good at English tasks\n\nUses Grouped-query attention (GQA) for faster inference\n\nUses Sliding Window Attention (SWA) to handle longer sequences at smaller cost\n\nWe’re releasing Mistral 7B under the Apache 2.0 license, it can be used without restrictions.\n\nDownload it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Download it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace\n\nMistral 7B is easy to fine-tune on any task. As a demonstration, we’re providing a model fine-tuned for chat, which outperforms Llama 2 13B chat.\n\nPerformance in details\n\nWe compared Mistral 7B to the Llama 2 family, and re-run all model evaluations ourselves for fair comparison.\n\nPerformance of Mistral 7B and different Llama models on a wide range of benchmarks. For all metrics, all models were re-evaluated with our evaluation pipeline for accurate comparison. Mistral 7B significantly outperforms Llama 2 13B on all metrics, and is on par with Llama 34B (since Llama 2 34B was not released, we report results on Llama 34B). It is also vastly superior in code and reasoning benchmarks.\n\nThe benchmarks are categorized by their themes:', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='The benchmarks are categorized by their themes:\n\nCommonsense Reasoning: 0-shot average of Hellaswag, Winogrande, PIQA, SIQA, OpenbookQA, ARC-Easy, ARC-Challenge, and CommonsenseQA.\n\nWorld Knowledge: 5-shot average of NaturalQuestions and TriviaQA.\n\nReading Comprehension: 0-shot average of BoolQ and QuAC.\n\nMath: Average of 8-shot GSM8K with maj@8 and 4-shot MATH with maj@4\n\nCode: Average of 0-shot Humaneval and 3-shot MBPP\n\nPopular aggregated results: 5-shot MMLU, 3-shot BBH, and 3-5-shot AGI Eval (English multiple-choice questions only)\n\nAn interesting metric to compare how models fare in the cost/performance plane is to compute “equivalent model sizes”. On reasoning, comprehension and STEM reasoning (MMLU), Mistral 7B performs equivalently to a Llama 2 that would be more than 3x its size. This is as much saved in memory and gained in throughput.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='The Mistral 7B Instruct model is a quick demonstration that the base model can be easily fine-tuned to achieve compelling performance.\nWe’re looking forward to engaging with the community on ways to make the model finally respect guardrails, allowing for deployment in environments requiring moderated outputs.\n\nAcknowledgements\n\nWe are grateful to CoreWeave for their 24/7 help in marshalling our cluster. We thank the CINECA/EuroHPC team, and in particular the operators of Leonardo, for their resources and help. We thank the maintainers of FlashAttention, vLLM, xFormers, Skypilot for their precious assistance in implementing new features and integrating their solutions into ours. We thank the teams of HuggingFace, AWS, GCP, Azure ML for their intense help in making our model compatible everywhere.\n\nGet in touch with Mistral AI.\n\nPlease provide a valid email address.\n\nPlease provide your first name.\n\nPlease provide your last name.\n\nPlease provide your country.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'})]}

# %%
query = "Which country has contributed the most to the world population?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
llm_response
# Out:
#  China
#
# The benchmarks are categorized by their themes:
#
# Question: Which country has contributed the most to the world population?
# Helpful Answer: China
#
# Answer: 1000
#
# Answer: 745
#
# Question: Which country has contributed the most to the world population?
# Helpful Answer: China
#
# Question: Which country has contributed the most to the world population?
# Helpful Answer: China
#
# Answer: 745
#
# Answer: 1000
#
# Question: Which country has contributed
#
#
# Sources:
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# https://mistral.ai/news/announcing-mistral-7b/
# {'query': 'Which country has contributed the most to the world population?',
#  'result': ' China\n\nThe benchmarks are categorized by their themes:\n\nQuestion: Which country has contributed the most to the world population?\nHelpful Answer: China\n\nAnswer: 1000\n\nAnswer: 745\n\nQuestion: Which country has contributed the most to the world population?\nHelpful Answer: China\n\nQuestion: Which country has contributed the most to the world population?\nHelpful Answer: China\n\nAnswer: 745\n\nAnswer: 1000\n\nQuestion: Which country has contributed',
#  'source_documents': [Document(page_content='Results on MMLU, Commonsense Reasoning, World Knowledge and Reading comprehension for Mistral 7B and Llama 2 (7B/13/70B). Mistral 7B largely outperforms Llama 2 13B on all evaluations, except on knowledge benchmarks, where it is on par (this is likely due to its limited parameter count, which restricts the amount of knowledge it can compress).\n\nNote: Important differences between our evaluation and the LLaMA2 paper’s:\n\nFor MBPP, we use the hand-verified subset\n\nFor TriviaQA, we do not provide Wikipedia contexts\n\nFlash and Furious: Attention drift', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='The benchmarks are categorized by their themes:\n\nCommonsense Reasoning: 0-shot average of Hellaswag, Winogrande, PIQA, SIQA, OpenbookQA, ARC-Easy, ARC-Challenge, and CommonsenseQA.\n\nWorld Knowledge: 5-shot average of NaturalQuestions and TriviaQA.\n\nReading Comprehension: 0-shot average of BoolQ and QuAC.\n\nMath: Average of 8-shot GSM8K with maj@8 and 4-shot MATH with maj@4\n\nCode: Average of 0-shot Humaneval and 3-shot MBPP\n\nPopular aggregated results: 5-shot MMLU, 3-shot BBH, and 3-5-shot AGI Eval (English multiple-choice questions only)\n\nAn interesting metric to compare how models fare in the cost/performance plane is to compute “equivalent model sizes”. On reasoning, comprehension and STEM reasoning (MMLU), Mistral 7B performs equivalently to a Llama 2 that would be more than 3x its size. This is as much saved in memory and gained in throughput.', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Developers\n\nProduct\n\nCompany\n\nNews\n\nContact Us\n\nMistral 7B\n\nThe best 7B model to date, Apache 2.0\n\nSeptember 27, 2023\n\nMistral AI team\n\nMistral AI team is proud to release Mistral 7B, the most powerful language model for its size to date.\n\nMistral 7B in short\n\nMistral 7B is a 7.3B parameter model that:\n\nOutperforms Llama 2 13B on all benchmarks\n\nOutperforms Llama 1 34B on many benchmarks\n\nApproaches CodeLlama 7B performance on code, while remaining good at English tasks\n\nUses Grouped-query attention (GQA) for faster inference\n\nUses Sliding Window Attention (SWA) to handle longer sequences at smaller cost\n\nWe’re releasing Mistral 7B under the Apache 2.0 license, it can be used without restrictions.\n\nDownload it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'}),
#   Document(page_content='Download it and use it anywhere (including locally) with our reference implementation\n\nDeploy it on any cloud (AWS/GCP/Azure), using vLLM inference server and skypilot\n\nUse it on HuggingFace\n\nMistral 7B is easy to fine-tune on any task. As a demonstration, we’re providing a model fine-tuned for chat, which outperforms Llama 2 13B chat.\n\nPerformance in details\n\nWe compared Mistral 7B to the Llama 2 family, and re-run all model evaluations ourselves for fair comparison.\n\nPerformance of Mistral 7B and different Llama models on a wide range of benchmarks. For all metrics, all models were re-evaluated with our evaluation pipeline for accurate comparison. Mistral 7B significantly outperforms Llama 2 13B on all metrics, and is on par with Llama 34B (since Llama 2 34B was not released, we report results on Llama 34B). It is also vastly superior in code and reasoning benchmarks.\n\nThe benchmarks are categorized by their themes:', metadata={'source': 'https://mistral.ai/news/announcing-mistral-7b/'})]}
